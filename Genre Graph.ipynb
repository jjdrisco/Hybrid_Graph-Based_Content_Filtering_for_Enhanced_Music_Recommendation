# %%
import pandas as pd

# Load the data, removing leading and trailing spaces and dropping duplicates
df = pd.read_csv('maharshipandya-spotify-tracks-dataset.csv').iloc[:,1:]

# %%
df[df['track_genre'].isin(['acoustic'])]
# Out:
#                    track_id                 artists  \
# 0    5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1    4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2    1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3    6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4    5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ..                      ...                     ...
# 995  1epXnhFfFToKeugQWBCsQg              Harley Poe
# 996  5aBpIqXfktr9SSwyAi8Hlj               Taj Mahal
# 997  1ZD2MlKRTYKI8oewOt28mc              Pigeon Pit
# 998  3zVMv0mxjnJRw2BX5ryCqT             Chuck Ragan
# 999  5ieA3sRjDvak7oTrbrR6mV            Frank Turner
#
#                                             album_name  \
# 0                                               Comedy
# 1                                     Ghost (Acoustic)
# 2                                       To Begin Again
# 3    Crazy Rich Asians (Original Motion Picture Sou...
# 4                                              Hold On
# ..                                                 ...
# 995                            Wretched. Filthy. Ugly.
# 996                            The Essential Taj Mahal
# 997                                          Treehouse
# 998                                    Covering Ground
# 999                                           Songbook
#
#                              track_name  popularity  duration_ms  explicit  \
# 0                                Comedy          73       230666     False
# 1                      Ghost - Acoustic          55       149610     False
# 2                        To Begin Again          57       210826     False
# 3            Can't Help Falling In Love          71       201933     False
# 4                               Hold On          82       198853     False
# ..                                  ...         ...          ...       ...
# 995                               Maria          26       196226      True
# 996  Corinna - From "The Natch'l Blues"          29       180920     False
# 997                           Tall Cans          26       186461      True
# 998               You Get What You Give          26       217293     False
# 999                   Four Simple Words          25       297093      True
#
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.676  0.4610    1    -6.746     0       0.1430       0.03220
# 1           0.420  0.1660    1   -17.235     1       0.0763       0.92400
# 2           0.438  0.3590    0    -9.734     1       0.0557       0.21000
# 3           0.266  0.0596    0   -18.515     1       0.0363       0.90500
# 4           0.618  0.4430    2    -9.681     1       0.0526       0.46900
# ..            ...     ...  ...       ...   ...          ...           ...
# 995         0.633  0.8320    0    -6.840     1       0.0863       0.02740
# 996         0.621  0.2940    9   -13.468     1       0.1100       0.55800
# 997         0.648  0.3890    4    -8.275     1       0.0927       0.80700
# 998         0.303  0.5060    9    -6.890     1       0.0325       0.49600
# 999         0.335  0.8810    0    -6.480     1       0.0934       0.00805
#
#      instrumentalness  liveness  valence    tempo  time_signature track_genre
# 0            0.000001    0.3580    0.715   87.917               4    acoustic
# 1            0.000006    0.1010    0.267   77.489               4    acoustic
# 2            0.000000    0.1170    0.120   76.332               4    acoustic
# 3            0.000071    0.1320    0.143  181.740               3    acoustic
# 4            0.000000    0.0829    0.167  119.949               4    acoustic
# ..                ...       ...      ...      ...             ...         ...
# 995          0.000008    0.0957    0.838  130.912               4    acoustic
# 996          0.000025    0.0946    0.728   78.599               4    acoustic
# 997          0.000098    0.1100    0.378   86.360               4    acoustic
# 998          0.000000    0.1780    0.412  161.463               3    acoustic
# 999          0.000000    0.1100    0.173   96.900               4    acoustic
#
# [1000 rows x 20 columns]

# %%
import networkx as nx
from pyvis.network import Network

# Initialize graph
G = nx.Graph()

# Define genre groups
genre_groups = {
    "blues": ['sad', 'jazz', 'gospel'],
    "country": ['honky-tonk', 'bluegrass', 'folk'],
    "r-n-b": ['groove', 'soul', 'funk', 'disco'],
    "rock": ['rock-n-roll', 'rockabilly', 'j-rock', 'hard-rock', 'psych-rock', 'punk-rock', 'punk',
              'alt-rock', 'alternative', 'grunge', 'emo', 'indie', 'indie-pop', 'hardcore', 'metal', 'black-metal',
              'death-metal', 'heavy-metal', 'metalcore', 'grindcore', 'goth'],
    "pop": ['power-pop', 'synth-pop', 'songwriter', 'happy', 'british', 'j-pop', 'j-idol', 'k-pop', 'mandopop',
             'cantopop', 'indian', 'brazil', 'mpb', 'swedish', 'afrobeat', 'pop-film'],
    "reggae": ['dancehall', 'dub', 'ska', 'latin', 'latino'],
    "hip-hop": [],
    "breakbeat": ['drum-and-bass', 'trip-hop'],
    'house': ['deep-house', 'chicago-house', 'progressive-house','french'],
    'techno': ['detroit-techno', 'minimal-techno'],
    "edm": ['techno', 'detroit-techno', 'minimal-techno', 'electro', 'electronic', 'dubstep',
                   'idm', 'club', 'hardstyle', 'trance', 'j-dance', 'party'],
    "ambient": ['chill', 'study', 'sleep'],
    "industrial": [],
    'acoustic': [],
    "classical": ['piano', 'opera', 'romance'],
    'world-music': ['turkish', 'iranian', 'malay','tango', 'samba', 'pagode', 'salsa', 'sertanejo', 'forro', 'spanish'],
    "children": ['kids', 'disney', 'show-tunes', 'anime', 'comedy']
}

# Define edges
edges = [
    ('country', 'honky-tonk', 'subgenre'), ('country', 'bluegrass', 'subgenre'), ('bluegrass', 'folk', 'subgenre'),
    ('country', 'rock-n-roll', 'influence'),
    ('r-n-b', 'rock-n-roll', 'influence'), ('r-n-b', 'blues', 'influence'), ('r-n-b', 'soul', 'influence'),
    ('r-n-b', 'jazz', 'influence'), ('funk', 'soul', 'influence'), ('funk', 'disco', 'influence'),
    ('funk', 'psych-rock', 'influence'), ('funk', 'jazz', 'influence'), ('disco', 'synth-pop', 'influence'),
    ('disco', 'soul', 'influence'), ('disco', 'chicago-house', 'influence'), ('groove', 'funk', 'influence'),
    ('groove', 'soul', 'influence'), ('groove', 'jazz', 'influence'), ('funk', 'french', 'influence'),
    ('rock-n-roll', 'rockabilly', 'subgenre'), ('rockabilly', 'country', 'influence'),
    ('punk-rock', 'punk', 'subgenre'), ('punk-rock', 'grunge', 'influence'), ('punk-rock', 'metal', 'influence'),
    ('punk-rock', 'hardcore', 'influence'), ('punk', 'heavy-metal', 'influence'), ('punk', 'metalcore', 'influence'),
    ('punk', 'indie', 'influence'), ('hardcore', 'heavy-metal', 'influence'), ('hardcore', 'metalcore', 'influence'),
    ('hardcore', 'indie', 'influence'), ('hardcore', 'punk-rock', 'influence'), ('alt-rock', 'indie-pop', 'influence'),
    ('alt-rock', 'indie', 'influence'), ('alt-rock', 'grunge', 'influence'), ('alternative', 'indie-pop', 'influence'),
    ('alternative', 'indie', 'influence'), ('alternative', 'grunge', 'influence'), ('indie', 'indie-pop', 'influence'),
    ('alt-rock', 'alternative', 'influence'), ('alternative', 'indie', 'influence'), ('emo', 'hardcore', 'influence'),
    ('emo', 'punk', 'influence'), ('emo', 'indie-pop', 'influence'), ('goth', 'punk-rock', 'influence'),
    ('goth', 'industrial', 'influence'), ('grunge', 'punk-rock', 'influence'), ('grunge', 'metal', 'influence'),
    ('metal', 'psych-rock', 'influence'), ('psych-rock', 'jazz', 'influence'), ('psych-rock', 'funk', 'influence'),
    ('synth-pop', 'dance', 'influence'), ('synth-pop', 'pop', 'influence'),
    ('british', 'indie', 'influence'), ('indie-pop', 'pop', 'influence'), ('reggae', 'dancehall', 'subgenre'),
    ('reggae', 'ska', 'influence'), ('reggae', 'dub', 'influence'), ('dancehall', 'ska', 'influence'),
    ('dancehall', 'latin', 'influence'), ('dancehall', 'latino', 'influence'), ('ska', 'soul', 'influence'),
    ('ska', 'r-n-b', 'influence'), ('hip-hop', 'trip-hop', 'influence'), ('hip-hop', 'breakbeat', 'influence'),
    ('breakbeat', 'dubstep', 'influence'), ('breakbeat', 'trip-hop', 'influence'), ('drum-and-bass', 'techno', 'influence'),
    ('dubstep', 'edm', 'influence'), ('detroit-techno', 'chicago-house', 'influence'),
    ('detroit-techno', 'trance', 'influence'), ('deep-house', 'chicago-house', 'influence'),
    ('deep-house', 'french', 'influence'), ('trance', 'ambient', 'influence'), ('anime', 'j-pop', 'influence'),
    ('anime', 'j-idol', 'influence'), ('spanish', 'latin', 'influence'), ('gospel', 'r-n-b', 'derivative'), 
    ('gospel', 'soul', 'derivative'), ('sad', 'chill', 'connect'), ('study', 'chill', 'connect'), 
    ('show-tunes', 'pop-film', 'connect'), ('show-tunes', 'disney', 'connect'), ('comedy', 'show-tunes', 'connect'),
    ("rockabilly", "rock-n-roll", "subgenre"), ("rockabilly", "country", "influence"),
    ("punk-rock", "punk", "subgenre"), ("punk-rock", "grunge", "influence"), ("punk-rock", "metal", "influence"),
    ("punk-rock", "hardcore", "influence"), ("punk", "heavy-metal", "influence"), ("punk", "metalcore", "influence"),
    ("punk", "indie", "influence"), ("hardcore", "heavy-metal", "influence"), ("hardcore", "metalcore", "influence"),
    ("hardcore", "indie", "influence"), ("hardcore", "punk-rock", "influence"),
    ("alt-rock", "indie-pop", "influence"), ("alt-rock", "indie", "influence"), ("alt-rock", "grunge", "influence"),
    ("alternative", "indie-pop", "influence"), ("alternative", "indie", "influence"), ("alternative", "grunge", "influence"),
    ("indie", "indie-pop", "influence"), ("alt-rock", "alternative", "influence"), ("alternative", "indie", "influence"),
    ("emo", "hardcore", "influence"), ("emo", "punk", "influence"), ("emo", "indie-pop", "influence"),
    ("goth", "punk-rock", "influence"), ("goth", "industrial", "influence"),
    ("grunge", "punk-rock", "influence"), ("grunge", "metal", "influence"),
    ("grindcore", "heavy-metal", "influence"), ("metal", "punk-rock", "influence"), ("metal", "psych-rock", "influence"),
    ("black-metal", "heavy-metal", "influence"), ("death-metal", "metalcore", "influence"), ("death-metal", "heavy-metal", "influence"),
    ("heavy-metal", "black-metal", "influence"), ("heavy-metal", "death-metal", "influence"), ("heavy-metal", "grindcore", "influence"),
    ("heavy-metal", "hardcore", "influence"), ("heavy-metal", "punk", "influence"),
    ("metalcore", "hardcore", "influence"), ("metalcore", "death-metal", "influence"), ("metalcore", "punk", "influence"),
    ("psych-rock", "goth", "influence"), ("psych-rock", "metal", "influence"), ("psych-rock", "jazz", "influence"), ("psych-rock", "funk", "influence"),
    ('k-pop', 'j-pop', 'influence'), ("idm", "detroit-techno", "influence"), ("idm", "techno", "influence"), ("idm", "breakbeat", "influence"),
    ("hardstyle", "trance", "influence"), ("hardstyle", "techno", "influence"), ("hardstyle", "house", "influence"),
    ("trance", "house", "influence"), ("trance", "ambient", "influence"), ("trance", "detroit-techno", "influence"),
    ("j-dance", "j-pop", "influence"), ("j-dance", "house", "influence"), ("j-dance", "techno", "influence"), ("j-dance", "trance", "influence"),
    ("electro", "house", "influence"), ("electro", "techno", "influence"), ("electro", "edm", "influence"), ("electro", "french", "influence"),
    ("breakbeat", "dubstep", "influence"), ("breakbeat", "trip-hop", "influence"), ("drum-and-bass", "techno", "influence"),
    ("dubstep", "edm", "influence"), ("detroit-techno", "chicago-house", "influence"), ("detroit-techno", "trance", "influence"),
    ("deep-house", "chicago-house", "influence"), ("deep-house", "french", "influence"), ("techno", "detroit-techno", "influence"),
    ("techno", "minimal-techno", "influence"), ("detroit-techno", "minimal-techno", "influence"), ("detroit-techno", "electro", "influence"),
    ("electro", "funk", "influence"), ("chicago-house", "disco", "influence"), ("chicago-house", "ambient", "influence"), ('dance', 'edm', 'influence'),
    ('dance', 'hip-hop', 'influence'), ('dance', 'disco', 'influence'), ('dance', 'dancehall', 'influence'),
    ('electro', 'acoustic', 'influence'), ('industrial', 'techno', 'influence'), ('world-music', 'ambient', 'influence')
]
# acoustic between folk, jazz, and classical
# join classical to 
# Create Graph
for group, subgenres in genre_groups.items():
    for genre in subgenres:
        G.add_node(genre, group=group)
        G.add_edge(group, genre, label='subgenre')
for edge in edges:
    G.add_edge(edge[0], edge[1], label=edge[2])
    


# Visualization
net = Network(notebook=True, height='750px', width='100%', bgcolor='#222222', font_color='white')
net.from_nx(G)
net.show("music_genre_graph.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# music_genre_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="music_genre_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
shortest_paths = nx.single_source_shortest_path(G, source="country")

for genre, path in shortest_paths.items():
    print(f"Shortest path from rock to {genre}: {path}")
    
pick = np.random.choice(df["track_genre"].unique())
# Out:
# Shortest path from rock to country: ['country']
# Shortest path from rock to honky-tonk: ['country', 'honky-tonk']
# Shortest path from rock to bluegrass: ['country', 'bluegrass']
# Shortest path from rock to folk: ['country', 'folk']
# Shortest path from rock to rock-n-roll: ['country', 'rock-n-roll']
# Shortest path from rock to rockabilly: ['country', 'rockabilly']
# Shortest path from rock to rock: ['country', 'rock-n-roll', 'rock']
# Shortest path from rock to r-n-b: ['country', 'rock-n-roll', 'r-n-b']
# Shortest path from rock to j-rock: ['country', 'rock-n-roll', 'rock', 'j-rock']
# Shortest path from rock to hard-rock: ['country', 'rock-n-roll', 'rock', 'hard-rock']
# Shortest path from rock to psych-rock: ['country', 'rock-n-roll', 'rock', 'psych-rock']
# Shortest path from rock to punk-rock: ['country', 'rock-n-roll', 'rock', 'punk-rock']
# Shortest path from rock to punk: ['country', 'rock-n-roll', 'rock', 'punk']
# Shortest path from rock to alt-rock: ['country', 'rock-n-roll', 'rock', 'alt-rock']
# Shortest path from rock to alternative: ['country', 'rock-n-roll', 'rock', 'alternative']
# Shortest path from rock to grunge: ['country', 'rock-n-roll', 'rock', 'grunge']
# Shortest path from rock to emo: ['country', 'rock-n-roll', 'rock', 'emo']
# Shortest path from rock to indie: ['country', 'rock-n-roll', 'rock', 'indie']
# Shortest path from rock to indie-pop: ['country', 'rock-n-roll', 'rock', 'indie-pop']
# Shortest path from rock to hardcore: ['country', 'rock-n-roll', 'rock', 'hardcore']
# Shortest path from rock to metal: ['country', 'rock-n-roll', 'rock', 'metal']
# Shortest path from rock to black-metal: ['country', 'rock-n-roll', 'rock', 'black-metal']
# Shortest path from rock to death-metal: ['country', 'rock-n-roll', 'rock', 'death-metal']
# Shortest path from rock to heavy-metal: ['country', 'rock-n-roll', 'rock', 'heavy-metal']
# Shortest path from rock to metalcore: ['country', 'rock-n-roll', 'rock', 'metalcore']
# Shortest path from rock to grindcore: ['country', 'rock-n-roll', 'rock', 'grindcore']
# Shortest path from rock to goth: ['country', 'rock-n-roll', 'rock', 'goth']
# Shortest path from rock to groove: ['country', 'rock-n-roll', 'r-n-b', 'groove']
# Shortest path from rock to soul: ['country', 'rock-n-roll', 'r-n-b', 'soul']
# Shortest path from rock to funk: ['country', 'rock-n-roll', 'r-n-b', 'funk']
# Shortest path from rock to disco: ['country', 'rock-n-roll', 'r-n-b', 'disco']
# Shortest path from rock to blues: ['country', 'rock-n-roll', 'r-n-b', 'blues']
# Shortest path from rock to jazz: ['country', 'rock-n-roll', 'r-n-b', 'jazz']
# Shortest path from rock to ska: ['country', 'rock-n-roll', 'r-n-b', 'ska']
# Shortest path from rock to gospel: ['country', 'rock-n-roll', 'r-n-b', 'gospel']
# Shortest path from rock to british: ['country', 'rock-n-roll', 'rock', 'indie', 'british']
# Shortest path from rock to pop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop']
# Shortest path from rock to industrial: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial']
# Shortest path from rock to french: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'french']
# Shortest path from rock to electro: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro']
# Shortest path from rock to synth-pop: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'synth-pop']
# Shortest path from rock to chicago-house: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house']
# Shortest path from rock to dance: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'dance']
# Shortest path from rock to sad: ['country', 'rock-n-roll', 'r-n-b', 'blues', 'sad']
# Shortest path from rock to reggae: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'reggae']
# Shortest path from rock to dancehall: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'dancehall']
# Shortest path from rock to power-pop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'power-pop']
# Shortest path from rock to songwriter: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'songwriter']
# Shortest path from rock to happy: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'happy']
# Shortest path from rock to j-pop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-pop']
# Shortest path from rock to j-idol: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-idol']
# Shortest path from rock to k-pop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'k-pop']
# Shortest path from rock to mandopop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'mandopop']
# Shortest path from rock to cantopop: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'cantopop']
# Shortest path from rock to indian: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'indian']
# Shortest path from rock to brazil: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'brazil']
# Shortest path from rock to mpb: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'mpb']
# Shortest path from rock to swedish: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'swedish']
# Shortest path from rock to afrobeat: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'afrobeat']
# Shortest path from rock to pop-film: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'pop-film']
# Shortest path from rock to techno: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial', 'techno']
# Shortest path from rock to house: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'french', 'house']
# Shortest path from rock to deep-house: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'french', 'deep-house']
# Shortest path from rock to edm: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'edm']
# Shortest path from rock to detroit-techno: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'detroit-techno']
# Shortest path from rock to acoustic: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'acoustic']
# Shortest path from rock to ambient: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient']
# Shortest path from rock to hip-hop: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'dance', 'hip-hop']
# Shortest path from rock to chill: ['country', 'rock-n-roll', 'r-n-b', 'blues', 'sad', 'chill']
# Shortest path from rock to dub: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'reggae', 'dub']
# Shortest path from rock to latin: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'reggae', 'latin']
# Shortest path from rock to latino: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'reggae', 'latino']
# Shortest path from rock to anime: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-pop', 'anime']
# Shortest path from rock to j-dance: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-pop', 'j-dance']
# Shortest path from rock to show-tunes: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'pop-film', 'show-tunes']
# Shortest path from rock to minimal-techno: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial', 'techno', 'minimal-techno']
# Shortest path from rock to drum-and-bass: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial', 'techno', 'drum-and-bass']
# Shortest path from rock to idm: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial', 'techno', 'idm']
# Shortest path from rock to hardstyle: ['country', 'rock-n-roll', 'rock', 'goth', 'industrial', 'techno', 'hardstyle']
# Shortest path from rock to progressive-house: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'french', 'house', 'progressive-house']
# Shortest path from rock to trance: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'french', 'house', 'trance']
# Shortest path from rock to electronic: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'edm', 'electronic']
# Shortest path from rock to dubstep: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'edm', 'dubstep']
# Shortest path from rock to club: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'edm', 'club']
# Shortest path from rock to party: ['country', 'rock-n-roll', 'r-n-b', 'funk', 'electro', 'edm', 'party']
# Shortest path from rock to study: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'study']
# Shortest path from rock to sleep: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'sleep']
# Shortest path from rock to world-music: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music']
# Shortest path from rock to trip-hop: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'dance', 'hip-hop', 'trip-hop']
# Shortest path from rock to breakbeat: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'dance', 'hip-hop', 'breakbeat']
# Shortest path from rock to spanish: ['country', 'rock-n-roll', 'r-n-b', 'ska', 'reggae', 'latin', 'spanish']
# Shortest path from rock to children: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-pop', 'anime', 'children']
# Shortest path from rock to disney: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'pop-film', 'show-tunes', 'disney']
# Shortest path from rock to comedy: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'pop-film', 'show-tunes', 'comedy']
# Shortest path from rock to turkish: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'turkish']
# Shortest path from rock to iranian: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'iranian']
# Shortest path from rock to malay: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'malay']
# Shortest path from rock to tango: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'tango']
# Shortest path from rock to samba: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'samba']
# Shortest path from rock to pagode: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'pagode']
# Shortest path from rock to salsa: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'salsa']
# Shortest path from rock to sertanejo: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'sertanejo']
# Shortest path from rock to forro: ['country', 'rock-n-roll', 'r-n-b', 'disco', 'chicago-house', 'ambient', 'world-music', 'forro']
# Shortest path from rock to kids: ['country', 'rock-n-roll', 'rock', 'indie-pop', 'pop', 'j-pop', 'anime', 'children', 'kids']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 for genre, path in shortest_paths.items():
#       4     print(f"Shortest path from rock to {genre}: {path}")
# ----> 6 pick = np.random.choice(df["track_genre"].unique())
#
# NameError: name 'np' is not defined

# %%
shortest_paths[pick]
# Out:
# ['country',
#  'rock-n-roll',
#  'r-n-b',
#  'ska',
#  'reggae',
#  'latin',
#  'spanish',
#  'classical',
#  'pagode']
